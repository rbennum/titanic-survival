# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# # Predicting Survival on Titanic: Improvement
#
# This notebook presents a continuation on the last notebook as we are trying to achieve
# 85% accuracy from our 77% base accuracy. We are also trying to implement a better
# workflow using `sklearn`'s `Pipeline`, splitting the train dataset, applying cross-validation,
# spending our time inspecting features to learn more on why, before challenging back
# the test dataset from Kaggle.
#
# It would be a fun journey ahead. Stay tuned.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split

from src.utils import skim_data

import src.transformers as trf

# %% [markdown]
# ## Reading Datasets

# %%
df_train = pd.read_csv('input/train.csv')
df_test = pd.read_csv('input/test.csv')

# %% [markdown]
# Then from `df_train` I can simply created the famous `X` and `y` variables:

# %%
X = df_train.drop('Survived', axis=1)
y = df_train['Survived']

# %% [markdown]
# ## The Workflow
#
# There are several steps that I want to try in this improvement:
#
# - Train-Test Split
#
# Since testing on Kaggle has a limit, it would be best for me to test my model on
# a data split from the existing training dataset. I decide to spent 20% of the training
# dataset for my local testing process.
#
# - Hyperparameter tuning & cross-validation
#
# Hyperparameter is the external configuration settings
#
# - Refit on all `X` training data
# - Evaluation on `y`
# - Refit on all `df_train` data
# - Evaluation on Kaggle's `df_test` data

# %% [markdown]
# ### Split Train Dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23, stratify=y)

# %% [markdown]
# Let's see if our datasets have splitted fairly.

# %%
(
    y_train.value_counts() / len(y_train)
)
# Out:
# Survived
# 0    0.616573
# 1    0.383427
# Name: count, dtype: float64

# %%
(
    y_test.value_counts() / len(y_test)
)
# Out:
# Survived
# 0    0.614525
# 1    0.385475
# Name: count, dtype: float64

# %% [markdown]
# Both `y_train` and `y_test` have been splitted fairly, with class `0` stands at
# 61% and class `1` stands at 38%.

# %% [markdown]
# ### Hypertuning Parameters & Cross-Validation
#
# Thanks to `sklearn`'s `GridSearchVC`, we can run the hypertuning parameters and
# cross-validation in one go. There are two things that we need to decide before
# running them all:
#
# - Data Preprocessing and Feature Engineering
# - Define Parameter Grid

# %% [markdown]
# #### Data Preprocessing & Feature Engineering
#
# In our previous exploration, we already defined how we done both the data processing
# and feature engineering:
#
# - Extracts `Title` from `Name`, whilst replacing the rare ones.
# - Creates a `HasCabin` feature
# - Imputes missing `Age` values based on the `Title`.
# - Imputes missing `Embarked` values based on the mode, which is `S` for Southampton.
# - Encode the `Sex`, `Embarked`, and `Title`, which are the categorical features,
# by using `OneHotEncoding`.
# - Encode the `Pclass`, `Age`, `SibSp`, `Parch`, and `Fare`, which are the numerical
# features, by using `StandardScaler`.
# - Drop any features that aren't mentioned.
#
# But after exploring the discussion related to the challenge, I would like to test
# for a new feature, whether it's significant or not. It's called `family_size`, which
# combines the values of `SibSp` and `Parch` and adds one for the individual themselves.
# Let's try it out first before putting the previous processes into the pipeline.

# %% [markdown]
# ##### `FamilySize` Matters
#
# We'll start comparing it against the average of survived people.

# %%
df_temp = df_train.copy()

df_temp = (
    df_temp
    .assign(
        FamilySize=lambda x: x['SibSp'] + x['Parch'] + 1
    )
    .groupby('FamilySize', as_index=False)
    .agg({'Survived': 'mean'})
)

sns.barplot(data=df_temp, x='FamilySize', y='Survived')
# Out:
# <Axes: xlabel='FamilySize', ylabel='Survived'>

# %% [markdown]
# We can see that there is an apparent distinction comes from family size 1,
# family size 2-4, and family size > 5. Based on this distinction, I would create
# a binned property that divides this into three parts: small (family size 1),
# medium (family size 2-4), and large (family size > 5). This is also because
# binned properties are better used when utilizing linear-typed models. Since
# I'm using LinearSVC, in theory it would fit perfectly.

# %%
bins = [0, 1, 4, np.inf]
labels = ['small', 'medium', 'large']

df_temp['FamilyBin'] = pd.cut(df_temp['FamilySize'], bins=bins, labels=labels)

df_temp
# Out:
#    FamilySize  Survived FamilyBin
# 0           1  0.303538     small
# 1           2  0.552795    medium
# 2           3  0.578431    medium
# 3           4  0.724138    medium
# 4           5  0.200000     large
# 5           6  0.136364     large
# 6           7  0.333333     large
# 7           8  0.000000     large
# 8          11  0.000000     large

# %%
sns.barplot(data=df_temp, x='FamilyBin', y='Survived')
# Out:
# <Axes: xlabel='FamilyBin', ylabel='Survived'>

# %% [markdown]
# I have created a separate function called `FamilyBinFeatureExtractor`. Let's try it:

# %%
df_temp = df_train.copy()
family_binner = trf.FamilyBinExtractor()
df_temp = family_binner.fit_transform(df_temp)

display(df_temp)
# Out:
#     FamilyBin
# 0       Small
# 1       Small
# 2       Large
# 3       Large
# 4       Large
# ..        ...
# 886     Large
# 887     Large
# 888     Large
# 889     Large
# 890     Large
#
# [891 rows x 1 columns]

# %%
skim_data(df_test)
# Out:
# Total duplicate rows: 0
# DF shape: (418, 11)
#         feature    dtype  null_% negative_%  zero_%  n_unique  unique_%  \
# 0   PassengerId    int64   0.000        0.0     0.0       418    100.00
# 1        Pclass    int64   0.000        0.0     0.0         3      0.72
# 2          Name   object   0.000          -       -       418    100.00
# 3           Sex   object   0.000          -       -         2      0.48
# 4           Age  float64  20.574        0.0     0.0        79     18.90
# 5         SibSp    int64   0.000        0.0  67.703         7      1.67
# 6         Parch    int64   0.000        0.0  77.512         8      1.91
# 7        Ticket   object   0.000          -       -       363     86.84
# 8          Fare  float64   0.239        0.0   0.478       169     40.43
# 9         Cabin   object  78.230          -       -        76     18.18
# 10     Embarked   object   0.000          -       -         3      0.72
#
#                                         sample_values
# 0                           [892, 893, 894, 895, 896]
# 1                                           [3, 2, 1]
# 2   [Kelly, Mr. James, Wilkes, Mrs. James (Ellen N...
# 3                                      [male, female]
# 4                      [34.5, 47.0, 62.0, 27.0, 22.0]
# 5                                     [0, 1, 2, 3, 4]
# 6                                     [0, 1, 3, 2, 4]
# 7           [330911, 363272, 240276, 315154, 3101298]
# 8              [7.8292, 7.0, 9.6875, 8.6625, 12.2875]
# 9               [B45, E31, B57 B59 B63 B66, B36, A21]
# 10                                          [Q, S, C]

# %%
skim_data(df_train)
# Out:
# Total duplicate rows: 0
# DF shape: (891, 12)
#         feature    dtype  null_% negative_%  zero_%  n_unique  unique_%  \
# 0   PassengerId    int64   0.000        0.0     0.0       891    100.00
# 1      Survived    int64   0.000        0.0  61.616         2      0.22
# 2        Pclass    int64   0.000        0.0     0.0         3      0.34
# 3          Name   object   0.000          -       -       891    100.00
# 4           Sex   object   0.000          -       -         2      0.22
# 5           Age  float64  19.865        0.0     0.0        88      9.88
# 6         SibSp    int64   0.000        0.0  68.238         7      0.79
# 7         Parch    int64   0.000        0.0  76.094         7      0.79
# 8        Ticket   object   0.000          -       -       681     76.43
# 9          Fare  float64   0.000        0.0   1.684       248     27.83
# 10        Cabin   object  77.104          -       -       147     16.50
# 11     Embarked   object   0.224          -       -         3      0.34
#
#                                         sample_values
# 0                                     [1, 2, 3, 4, 5]
# 1                                              [0, 1]
# 2                                           [3, 1, 2]
# 3   [Braund, Mr. Owen Harris, Cumings, Mrs. John B...
# 4                                      [male, female]
# 5                      [22.0, 38.0, 26.0, 35.0, 54.0]
# 6                                     [1, 0, 3, 4, 2]
# 7                                     [0, 1, 2, 5, 3]
# 8   [A/5 21171, PC 17599, STON/O2. 3101282, 113803...
# 9                  [7.25, 71.2833, 7.925, 53.1, 8.05]
# 10                         [C85, C123, E46, G6, C103]
# 11                                          [S, C, Q]

# %%
sns.countplot(data=df_train, x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
crosstab_result = pd.crosstab(df_train['Pclass'], df_train['Survived'])
stacked_data = crosstab_result.stack().reset_index().rename(columns={0:'Count'})
sns.barplot(data=stacked_data, x='Pclass', y='Count', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
def _clean_title(title):
    if title in ['Ms', 'Mlle']: return 'Miss'
    if title in ['Mme']: return 'Mrs'
    return title

X_fit = df_train.copy()
titles = (
    X_fit['Name']
    .str.extract(r' ([A-Za-z]+)\.', expand=False)
    .apply(_clean_title)
)

counts = titles.value_counts()
threshold = counts.get('Master', 0)
rare_titles = counts[counts < threshold].index.tolist()
X_fit['Title'] = titles.replace(rare_titles, 'Rare')
display(X_fit['Title'])
title_median_map_ = X_fit.groupby('Title')['Age'].median().to_dict()
global_median_ = X['Age'].median()
display(title_median_map_)
display(global_median_)
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886    Rare
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object
# {'Master': 3.5, 'Miss': 21.0, 'Mr': 30.0, 'Mrs': 35.0, 'Rare': 48.5}
# np.float64(28.0)

# %%
df_train['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
import src.transformers as trf

imputer = trf.TitleBasedAgeImputer()
X_temp = imputer.fit_transform(X_train)
display(X_temp)
# Out:
#       Age Title
# 541   9.0  Miss
# 306  22.0  Miss
# 454  30.0    Mr
# 199  24.0  Miss
# 397  46.0    Mr
# ..    ...   ...
# 51   21.0    Mr
# 590  35.0    Mr
# 41   27.0   Mrs
# 23   28.0    Mr
# 673  31.0    Mr
#
# [712 rows x 2 columns]

# %%
from sklearn.compose import ColumnTransformer

import src.transformers as trf

preproccesor = ColumnTransformer(
    transformers=[
        ('family_binner', trf.FamilyBinExtractor(), ['SibSp', 'Parch']),
        ('cabin_indicator', trf.CabinExtractor(), ['Cabin']),
        ('title_age_imputer', trf.TitleBasedAgeImputer(), ['Name', 'Age']),
        ('fare_imputer', trf.FareImputer(), ['Fare']),
        ('embarked_imputer', trf.EmbarkedImputer(), ['Embarked']),
    ],
    remainder='passthrough'
)

X_temp = preproccesor.fit_transform(X_train)
feature_names = preproccesor.get_feature_names_out()
X_temp = pd.DataFrame(X_temp, columns=feature_names, index=X_train.index)
X_temp
# Out:
#     family_binner__FamilyBin cabin_indicator__HasCabin title_age_imputer__Age  \
# 541                    Large                         0                    9.0
# 306                   Single                         0                   22.0
# 454                   Single                         0                   30.0
# 199                   Single                         0                   24.0
# 397                   Single                         0                   46.0
# ..                       ...                       ...                    ...
# 51                    Single                         0                   21.0
# 590                   Single                         0                   35.0
# 41                     Small                         0                   27.0
# 23                    Single                         1                   28.0
# 673                   Single                         0                   31.0
#
#     title_age_imputer__Title fare_imputer__Fare embarked_imputer__Embarked  \
# 541                     Miss             31.275                          S
# 306                     Miss           110.8833                          C
# 454                       Mr               8.05                          S
# 199                     Miss               13.0                          S
# 397                       Mr               26.0                          S
# ..                       ...                ...                        ...
# 51                        Mr                7.8                          S
# 590                       Mr              7.125                          S
# 41                       Mrs               21.0                          S
# 23                        Mr               35.5                          S
# 673                       Mr               13.0                          S
#
#     remainder__PassengerId remainder__Pclass remainder__Sex  remainder__Ticket
# 541                    542                 3         female             347082
# 306                    307                 1         female              17421
# 454                    455                 3           male           A/5 2817
# 199                    200                 2         female             248747
# 397                    398                 2           male              28403
# ..                     ...               ...            ...                ...
# 51                      52                 3           male         A/4. 39886
# 590                    591                 3           male  STON/O 2. 3101273
# 41                      42                 2         female              11668
# 23                      24                 1           male             113788
# 673                    674                 2           male             244270
#
# [712 rows x 10 columns]

# %%
cat_columns = ['FamilyBin', 'Title', 'Embarked', 'Pclass', 'Sex']
num_columns = ['Age', 'Fare']
has_cabin_col = ['HasCabin']

# %% [markdown]
# ### Create Full Pipeline

# %%
import sklearn
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import LinearSVC

sklearn.set_config(transform_output="pandas") 

feature_engineering_processor = ColumnTransformer(
    transformers=[
        ('family_bin_extractor', trf.FamilyBinExtractor(), ['SibSp', 'Parch']),
        ('cabin_extractor', trf.CabinExtractor(), ['Cabin']),
        ('title_age_imputer', trf.TitleBasedAgeImputer(), ['Name', 'Age']),
        ('fare_imputer', trf.FareImputer(), ['Fare']),
        ('embarked_imputer', trf.EmbarkedImputer(), ['Embarked']),
    ],
    remainder='passthrough',
    verbose_feature_names_out=False
)
preprocessor = ColumnTransformer(
    transformers=[
        ('numeric', StandardScaler(), num_columns),
        ('categorical', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_columns),
        ('has_cabin', 'passthrough', has_cabin_col)
    ],
    verbose_feature_names_out=False
)
full_pipeline = Pipeline(
    steps=[
        ('feature_engineering', feature_engineering_processor),
        ('preprocessing', preprocessor),
        ('classifier', LinearSVC(random_state=23))
    ]
)

# %% [markdown]
# ### Cross-Validation & Hyperparameter Settings

# %% [markdown]
# Defining the parameter settings:

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

skf_splitter = StratifiedKFold(n_splits=10, shuffle=True, random_state=23)

param_grid = [
    {
        'classifier__penalty': ['l2'],
        'classifier__loss': ['squared_hinge'],
        'classifier__C': [0.1, 1, 10, 100],
        'classifier__max_iter': [10000]
    },
    {
        'classifier__penalty': ['l2'],
        'classifier__loss': ['hinge'],
        'classifier__dual': [True],
        'classifier__C': [0.1, 1, 10, 100],
        'classifier__max_iter': [10000]
    },
    {
        'classifier__penalty': ['l1'],
        'classifier__loss': ['squared_hinge'],
        'classifier__dual': [False],
        'classifier__C': [0.1, 1, 10, 100],
        'classifier__max_iter': [10000]
    }
]

# %% [markdown]
# Defining grid search:

# %%
grid_search = GridSearchCV(
    estimator=full_pipeline,
    param_grid=param_grid,
    cv=skf_splitter,
    scoring='accuracy',
    verbose=1,
    n_jobs=-1
)

# %%
print("Starting Grid Search...")
grid_search.fit(X_train, y_train)
print("Grid Search Complete.")

print("\n--- Best Results ---")
print(f"Best cross-validated score (Accuracy): {grid_search.best_score_:.4f}")
print("Best Hyperparameters:")
print(grid_search.best_params_)
# Out:
# Starting Grid Search...
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Grid Search Complete.
#
# --- Best Results ---
# Best cross-validated score (Accuracy): 0.8314
# Best Hyperparameters:
# {'classifier__C': 1, 'classifier__dual': False, 'classifier__loss': 'squared_hinge', 'classifier__max_iter': 10000, 'classifier__penalty': 'l1'}
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ### Test against `X_test`

# %%
from sklearn.metrics import accuracy_score, classification_report

final_predictions_on_test = grid_search.predict(X_test)

final_accuracy = accuracy_score(y_test, final_predictions_on_test)
print(f"Final Accuracy on the test set: {final_accuracy:.4f}")

print("\n--- Classification Report on Test Set ---")
print(classification_report(y_test, final_predictions_on_test))
# Out:
# Final Accuracy on the test set: 0.8324
#
# --- Classification Report on Test Set ---
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       110
#            1       0.84      0.70      0.76        69
#
#     accuracy                           0.83       179
#    macro avg       0.83      0.81      0.82       179
# weighted avg       0.83      0.83      0.83       179

# %% [markdown]
# ### Test against `df_test`

# %%
import time

submission_predictions = grid_search.predict(df_test)

submission_df = pd.DataFrame({
    'PassengerId': df_test['PassengerId'],
    'Survived': submission_predictions
})

filename = f'input/submission_{time.time()}.csv'
submission_df.to_csv(filename, index=False)

print(f"\nSubmission file '{filename}' created successfully!")
# Out:
# Submission file 'input/submission_1759241863.508.csv' created successfully!

# %% [markdown]
# The accuracy after running it against Kaggle test dataset is 0.77272. Not that much of an improvement.
# Let's see what we can do:
#
# - Turn everything into categorical data, which mean `Age` and `Fare` need to go
# under preprocessing step
# - Train using whole `df_train`, since right now we only use at least 90% of our train dataset.
# - Find out first why we got this score.

# %%
results_df = pd.DataFrame(grid_search.cv_results_)

# Find the row with the best parameters
best_model_results = results_df.loc[grid_search.best_index_]

print("Best Parameters Found:", grid_search.best_params_)
print("Mean CV Score (your .best_score_):", best_model_results['mean_test_score'])
print("Standard Deviation of CV Scores:", best_model_results['std_test_score'])

# Let's see the score for each individual fold
# The column names might be split_0_test_score, split_1_test_score, etc.
fold_score_columns = [f'split{i}_test_score' for i in range(grid_search.cv.n_splits)]
individual_fold_scores = best_model_results[fold_score_columns]

print("\nScores from each Cross-Validation Fold:")
display(individual_fold_scores)
# Out:
# Best Parameters Found: {'classifier__C': 1, 'classifier__dual': False, 'classifier__loss': 'squared_hinge', 'classifier__max_iter': 10000, 'classifier__penalty': 'l1'}
# Mean CV Score (your .best_score_): 0.8314358372456964
# Standard Deviation of CV Scores: 0.052324550522306584
#
# Scores from each Cross-Validation Fold:
# split0_test_score       0.875
# split1_test_score    0.805556
# split2_test_score    0.704225
# split3_test_score    0.887324
# split4_test_score     0.84507
# split5_test_score    0.802817
# split6_test_score    0.873239
# split7_test_score    0.873239
# split8_test_score     0.84507
# split9_test_score    0.802817
# Name: 9, dtype: object

# %%
best_pipeline = grid_search.best_estimator_

svc_model = best_pipeline.named_steps['classifier']

preprocessor = best_pipeline.named_steps['preprocessing']
feature_names = preprocessor.get_feature_names_out()

coefficients = pd.DataFrame({
    'feature': feature_names,
    'coefficient': svc_model.coef_[0]
}).sort_values('coefficient', ascending=False, key=abs).reset_index(drop=True)

print("\n--- Feature Importance (Coefficients) ---")
display(coefficients)
# Out:
# --- Feature Importance (Coefficients) ---
#              feature  coefficient
# 0    FamilyBin_Large    -1.081217
# 1       Title_Master     1.079911
# 2         Sex_female     0.530827
# 3           Sex_male    -0.434035
# 4           Pclass_3    -0.313025
# 5          Title_Mrs     0.222378
# 6           Pclass_1     0.206423
# 7                Age    -0.138277
# 8           HasCabin     0.130930
# 9           Title_Mr    -0.099945
# 10        Embarked_S    -0.090822
# 11  FamilyBin_Single     0.079605
# 12              Fare     0.072780
# 13        Embarked_Q     0.022629
# 14        Title_Miss     0.000000
# 15        Embarked_C     0.000000
# 16        Title_Rare     0.000000
# 17   FamilyBin_Small     0.000000
# 18          Pclass_2     0.000000

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# You should have a held-out test set (X_test, y_test)
# that the grid search has NEVER seen.
y_pred_test = grid_search.predict(X_test)

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_test)

# Display it
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Did not Survive', 'Survived'])
disp.plot()
plt.title("Confusion Matrix on Test Set")
plt.show()

# You can also print the classification report for more metrics
from sklearn.metrics import classification_report
print("\n--- Classification Report on Test Set ---")
print(classification_report(y_test, y_pred_test, target_names=['Did not Survive', 'Survived']))
# Out:
# --- Classification Report on Test Set ---
#                  precision    recall  f1-score   support
#
# Did not Survive       0.83      0.92      0.87       110
#        Survived       0.84      0.70      0.76        69
#
#        accuracy                           0.83       179
#       macro avg       0.83      0.81      0.82       179
#    weighted avg       0.83      0.83      0.83       179

# %%
# Add predictions and actuals to a copy of your test set for comparison
misclassified_df = X_test.copy()
misclassified_df['actual_survived'] = y_test
misclassified_df['predicted_survived'] = y_pred_test

# Filter for rows where the prediction was wrong
misclassified_df = misclassified_df[misclassified_df['actual_survived'] != misclassified_df['predicted_survived']]

print("\n--- Examples of Misclassified Passengers ---")
# Show a few examples of False Positives and False Negatives
print("\nPredicted SURVIVED, but DIED (False Positives):")
display(misclassified_df[misclassified_df['actual_survived'] == 0])

print("\nPredicted DIED, but SURVIVED (False Negatives):")
display(misclassified_df[misclassified_df['actual_survived'] == 1])
# Out:
# --- Examples of Misclassified Passengers ---
#
# Predicted SURVIVED, but DIED (False Positives):
#      PassengerId  Pclass                                               Name  \
# 357          358       2                          Funk, Miss. Annie Clemmer
# 14            15       3               Vestrom, Miss. Hulda Amanda Adolfina
# 423          424       3  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...
# 402          403       3                           Jussila, Miss. Mari Aina
# 617          618       3    Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# 293          294       3                                Haas, Miss. Aloisia
# 246          247       3              Lindahl, Miss. Agda Thorilda Viktoria
# 702          703       3                              Barbara, Miss. Saiide
# 419          420       3                          Van Impe, Miss. Catharina
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked  \
# 357  female  38.0      0      0     237671  13.0000   NaN        S
# 14   female  14.0      0      0     350406   7.8542   NaN        S
# 423  female  28.0      1      1     347080  14.4000   NaN        S
# 402  female  21.0      1      0       4137   9.8250   NaN        S
# 617  female  26.0      1      0  A/5. 3336  16.1000   NaN        S
# 293  female  24.0      0      0     349236   8.8500   NaN        S
# 246  female  25.0      0      0     347071   7.7750   NaN        S
# 702  female  18.0      0      1       2691  14.4542   NaN        C
# 419  female  10.0      0      2     345773  24.1500   NaN        S
#
#      actual_survived  predicted_survived
# 357                0                   1
# 14                 0                   1
# 423                0                   1
# 402                0                   1
# 617                0                   1
# 293                0                   1
# 246                0                   1
# 702                0                   1
# 419                0                   1
# Predicted DIED, but SURVIVED (False Negatives):
#      PassengerId  Pclass                                               Name  \
# 821          822       3                                  Lulic, Mr. Nikola
# 838          839       3                                    Chip, Mr. Chang
# 455          456       3                                 Jalsevac, Mr. Ivan
# 707          708       1                  Calderhead, Mr. Edward Pennington
# 207          208       3                        Albimona, Mr. Nassef Cassem
# 630          631       1               Barkworth, Mr. Algernon Henry Wilson
# 209          210       1                                   Blank, Mr. Henry
# 146          147       3       Andersson, Mr. August Edvard ("Wennerstrom")
# 25            26       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 701          702       1                   Silverthorne, Mr. Spencer Victor
# 68            69       3                    Andersson, Miss. Erna Alexandra
# 187          188       1      Romaine, Mr. Charles Hallace ("Mr C Rolmane")
# 599          600       1       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# 692          693       3                                       Lam, Mr. Ali
# 484          485       1                            Bishop, Mr. Dickinson H
# 569          570       3                                  Jonsson, Mr. Carl
# 127          128       3                          Madsen, Mr. Fridtjof Arne
# 429          430       3                 Pickard, Mr. Berk (Berk Trembisky)
# 570          571       2                                 Harris, Mr. George
# 414          415       3                          Sundman, Mr. Johan Julian
# 81            82       3                        Sheerlinck, Mr. Jan Baptist
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked  \
# 821    male  27.0      0      0             315098   8.6625   NaN        S
# 838    male  32.0      0      0               1601  56.4958   NaN        S
# 455    male  29.0      0      0             349240   7.8958   NaN        C
# 707    male  42.0      0      0           PC 17476  26.2875   E24        S
# 207    male  26.0      0      0               2699  18.7875   NaN        C
# 630    male  80.0      0      0              27042  30.0000   A23        S
# 209    male  40.0      0      0             112277  31.0000   A31        C
# 146    male  27.0      0      0             350043   7.7958   NaN        S
# 25   female  38.0      1      5             347077  31.3875   NaN        S
# 701    male  35.0      0      0           PC 17475  26.2875   E24        S
# 68   female  17.0      4      2            3101281   7.9250   NaN        S
# 187    male  45.0      0      0             111428  26.5500   NaN        S
# 599    male  49.0      1      0           PC 17485  56.9292   A20        C
# 692    male   NaN      0      0               1601  56.4958   NaN        S
# 484    male  25.0      1      0              11967  91.0792   B49        C
# 569    male  32.0      0      0             350417   7.8542   NaN        S
# 127    male  24.0      0      0            C 17369   7.1417   NaN        S
# 429    male  32.0      0      0  SOTON/O.Q. 392078   8.0500   E10        S
# 570    male  62.0      0      0        S.W./PP 752  10.5000   NaN        S
# 414    male  44.0      0      0  STON/O 2. 3101269   7.9250   NaN        S
# 81     male  29.0      0      0             345779   9.5000   NaN        S
#
#      actual_survived  predicted_survived
# 821                1                   0
# 838                1                   0
# 455                1                   0
# 707                1                   0
# 207                1                   0
# 630                1                   0
# 209                1                   0
# 146                1                   0
# 25                 1                   0
# 701                1                   0
# 68                 1                   0
# 187                1                   0
# 599                1                   0
# 692                1                   0
# 484                1                   0
# 569                1                   0
# 127                1                   0
# 429                1                   0
# 570                1                   0
# 414                1                   0
# 81                 1                   0

# %% [markdown]
# ### Test against whole `df_train`

# %%
grid_search_full = GridSearchCV(
    estimator=full_pipeline,
    param_grid=param_grid,
    cv=skf_splitter,
    scoring='accuracy',
    verbose=1,
    n_jobs=-1
)

# %%
X_train_all = df_train.drop('Survived', axis=1)
y_train_all = df_train['Survived']

print("Starting Grid Search...")
grid_search_full.fit(X_train_all, y_train_all)
print("Grid Search Complete.")

print("\n--- Best Results ---")
print(f"Best cross-validated score (Accuracy): {grid_search_full.best_score_:.4f}")
print("Best Hyperparameters:")
print(grid_search_full.best_params_)
# Out:
# Starting Grid Search...
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/bening/Courses/Pacmann.io/Portfolios/titanic-challenge/.venv/lib/python3.13/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Grid Search Complete.
#
# --- Best Results ---
# Best cross-validated score (Accuracy): 0.8317
# Best Hyperparameters:
# {'classifier__C': 0.1, 'classifier__dual': False, 'classifier__loss': 'squared_hinge', 'classifier__max_iter': 10000, 'classifier__penalty': 'l1'}

# %%
submission_predictions = grid_search_full.predict(df_test)

submission_df = pd.DataFrame({
    'PassengerId': df_test['PassengerId'],
    'Survived': submission_predictions
})

filename = f'input/submission_{time.time()}.csv'
submission_df.to_csv(filename, index=False)

print(f"\nSubmission file '{filename}' created successfully!")
# Out:
# Submission file 'input/submission_1759289759.9118872.csv' created successfully!

# %% [markdown]
# ## Improvement #2
#
# Base: 0.77033
#
# Improvement #1: 0.77272
#
# It's only 0.31% increment. Let's do it further by tweaking some features:
#
# - `IsAlone`: if `FamilySize` equals to 0.
# - Create binned features for `Age` and `Fare`.
# - Combined `Sex` and `Pclass`.

# %% [markdown]
# ### Parameter Grid

# %%
param_grid = {
    'classifier__penalty': ['l2', 'l1'],
    'classifier__loss': ['hinge', 'squared_hinge'],
    'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    'classifier__max_iter': [15000],
    'classifier__dual': [True, False, 'auto'],
    'classifier__fit_intercept': [True, False],
    'classifier__class_weight': [None, 'balanced']
}

# %% [markdown]
# ### New Feature: IsAlone
#
# Based on the misclassified dataframe, there are a lot of people who board alone
# misclassified as NOT SURVIVED.

# %%
df_temp = df_train.copy()
df_temp = (
    df_temp
    .assign(
        IsAlone=lambda x: np.where((x['SibSp'] + x['Parch']) == 0, 1, 0)
    )
)
sns.countplot(data=df_temp, x='IsAlone', hue='Survived')
# Out:
# <Axes: xlabel='IsAlone', ylabel='count'>

# %% [markdown]
# `IsAlone` == 1 can easily differentiate between Not Survived and Survived.

# %%
df_temp = df_train.copy()

# 1. First, create a total FamilySize column
df_temp['FamilySize'] = df_temp['SibSp'] + df_temp['Parch'] + 1 # Add 1 for the person themselves

# 2. Now, bin this FamilySize into categories
def categorize_family_size(size):
    if size == 1:
        return 'Alone'
    elif 2 <= size <= 4:
        return 'Small'
    else: # size >= 5
        return 'Large'

df_temp['FamilySizeBin'] = df_temp['FamilySize'].apply(categorize_family_size)


# --- Plotting the new, more detailed feature ---
plt.figure(figsize=(10, 6))
sns.countplot(data=df_temp, x='FamilySizeBin', hue='Survived', order=['Alone', 'Small', 'Large'])

# Add titles and labels for clarity
plt.title('Survival Count by Binned Family Size')
plt.xlabel('Family Size Category')
plt.ylabel('Count of Passengers')
plt.legend(title='Survival Status', labels=['Did Not Survive', 'Survived'])
plt.show()
